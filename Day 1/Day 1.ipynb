# %%
import pandas as pd

# %%
numbers = pd.Series([10, 20, 30, 40, 50])
print(numbers)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data = {
    "Name": ["Shravani", "Samiksha", "Prajwal"],
    "Age": [22, 25, 30],
    "City": ["Mumbai", "Pune", "Delhi"]
}
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#        Name  Age    City
# 0  Shravani   22  Mumbai
# 1  Samiksha   25    Pune
# 2   Prajwal   30   Delhi

# %%
print(df.head(2))
# Out:
#        Name  Age    City
# 0  Shravani   22  Mumbai
# 1  Samiksha   25    Pune

# %%
print(df.tail(2))
# Out:
#        Name  Age   City
# 1  Samiksha   25   Pune
# 2   Prajwal   30  Delhi

# %%
print(df.sample(2))
# Out:
#        Name  Age    City
# 1  Samiksha   25    Pune
# 0  Shravani   22  Mumbai

# %%
print(df.shape)
# Out:
# (3, 3)

# %%
print(df.columns)
# Out:
# Index(['Name', 'Age', 'City'], dtype='str')

# %%
print(df.dtypes)
# Out:
# Name      str
# Age     int64
# City      str
# dtype: object

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      str
#  1   Age     3 non-null      int64
#  2   City    3 non-null      str
# dtypes: int64(1), str(2)
# memory usage: 204.0 bytes
# None

# %%
print(df.describe())
# Out:
#              Age
# count   3.000000
# mean   25.666667
# std     4.041452
# min    22.000000
# 25%    23.500000
# 50%    25.000000
# 75%    27.500000
# max    30.000000
